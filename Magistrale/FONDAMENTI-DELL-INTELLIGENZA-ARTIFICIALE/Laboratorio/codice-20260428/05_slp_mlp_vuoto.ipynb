# %% [markdown]
# # SLP e MLP

# %% [markdown]
# Implementare un neurone artificiale che prenda in input $N = 8$ variabili:
# - Vedere il modello come una funzione $f: \mathbb{R}^N \rightarrow \mathbb{R}$ e definirla
# - Definire la funzione di attivazione di Heaviside
# - Definire la funzione di attivazione sigmoide con $\beta = 1$
# - Creare un neurone che usa la funzione di Heaviside come attivazione e un altro che usa la sigmoide.

# %%
import numpy as np

def heaviside(x):
    if x > 0:
        return 1
    else:
        return 0
    
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def pre_activation(x, w, b):
    return np.dot(x, w) + b

x = np.random.randn(1, 8)
w = np.random.randn(8, 1)
b = np.random.rand(1)

y = heaviside(pre_activation(x, w, b))

print(y)
# Out:
# 1

# %% [markdown]
# Importare il dataset $D$ presente nel file `data.csv`. Esso consiste di 100 esempi di $x \in \mathbb{R}^8$ e relative $y \in \mathbb{R}^4$.

# %%
import pandas as pd

import csv

df = pd.read_csv('data.csv')

X = df.iloc[:, :-4].values
Y = df.iloc[:, -4:].values

print(X.shape)
print(Y.shape)

print(X[0].shape)
# Out:
# (102, 8)
# (102, 4)
# (8,)

# %% [markdown]
# Provare i neurone artificiali precedentemente implementati su alcuni esempi di tale dataset:
# - Definire a random pesi e bias
# - Selezionare qualche istanza del dataset
# - Stampare il valore di output del neurone artificiale

# %%
w = ...
b = ...

y = ...

# %% [markdown]
# Definire un SLP
# $$
# f_{\theta} : \mathbb{R}^8 \rightarrow \mathbb{R}^4
# $$
# - Prima, provare a combinare i neuroni artificiali precedentemente implementati per definirlo
# - Poi, definire direttamente una nuova funzione
#
# Testare l'SLP sul dataset $D$.

# %% [markdown]
# Definire un MLP
# $$
# f_{\theta} : \mathbb{R}^8 \rightarrow \mathbb{R}^K \rightarrow \mathbb{R}^4
# $$
# con un solo strato nascosto, di dimensione a piacere.
#
# Testare l'MLP sul dataset $D$.
